# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import os

# %%
pd.set_option('display.max_columns', None)

# %%
os.listdir('data/clean')
# Out:
# ['income_clean.csv',
#  'education_clean.csv',
#  'commute_clean.csv',
#  'vehicles_clean.csv',
#  'masterdata.csv',
#  'population_clean.csv',
#  'housing_clean.csv',
#  'masterdata_allcounties.csv']

# %%
def load_data(category):
    loc = 'data/clean/' + category + '_clean.csv'
    return pd.read_csv(loc)

# %%
incomedata = load_data('income')
incomedata['fips'] = incomedata['id'].apply(lambda s: s[-5:])
incomedata = incomedata.drop(columns=['id'])
incomedata.head()
# Out:
#           geographic area name median income (family)  \
# 0      Jersey County, Illinois                  64773
# 1  Jo Daviess County, Illinois                  60381
# 2     Johnson County, Illinois                  47423
# 3        Kane County, Illinois                  77998
# 4    Kankakee County, Illinois                  59998
#
#   median income (nonfamily)  year   fips
# 0                     28125  2010  17083
# 1                     28266  2010  17085
# 2                     21378  2010  17087
# 3                     40333  2010  17089
# 4                     28864  2010  17091

# %%
educationdata = load_data('education')
educationdata['fips'] = educationdata['id'].apply(lambda s: s[-5:])
educationdata = educationdata.drop(columns=['id', 'geographic area name'])
educationdata.head()
# Out:
#    9th to 12th grade, no diploma  high school graduate (includes equivalency)  \
# 0                            8.4                                         36.7
# 1                            7.1                                         39.3
# 2                           16.1                                         32.3
# 3                            8.2                                         24.7
# 4                            9.2                                         35.0
#
#    some college, no degree  associate's degree  bachelor's degree  \
# 0                     25.1                 9.3                8.9
# 1                     19.6                 7.2               14.5
# 2                     24.6                 8.3                9.4
# 3                     19.6                 7.0               20.9
# 4                     23.9                 8.9               10.8
#
#    graduate or professional degree  year   fips
# 0                              7.2  2010  17083
# 1                              8.5  2010  17085
# 2                              3.4  2010  17087
# 3                             10.9  2010  17089
# 4                              6.6  2010  17091

# %%
def tofips_vehicle(s):
    fstr = str(int(s))
    if len(fstr) == 4:
        fstr = '0' + fstr
    return fstr

# %%
vehicledata = load_data('vehicles')
vehicledata.head()
# Out:
#    count           county  county geoid  registration year state
# 0     95   Calhoun County        1015.0             2018.0    fl
# 1   4584      Clay County        1027.0             2018.0    fl
# 2   4500  Escambia County        1053.0             2018.0    fl
# 3    216  Franklin County        1059.0             2018.0    fl
# 4    330   Jackson County        1071.0             2018.0    fl

# %%
vehicledata = load_data('vehicles')
vehicledata['fips'] = vehicledata['county geoid'].apply(tofips_vehicle)
vehicledata['year'] = vehicledata['registration year'].apply(lambda x: int(x))
vehicledata = vehicledata.drop(columns=['registration year', 'county geoid'])
vehicledata.head()
# Out:
#    count           county state   fips  year
# 0     95   Calhoun County    fl  01015  2018
# 1   4584      Clay County    fl  01027  2018
# 2   4500  Escambia County    fl  01053  2018
# 3    216  Franklin County    fl  01059  2018
# 4    330   Jackson County    fl  01071  2018

# %%
populationdata = load_data('population')
populationdata['fips'] = populationdata['id'].apply(lambda s: s[-5:])
populationdata = populationdata.drop(columns=['id', 'geographic area name'])
populationdata.head()
# Out:
#    total population  year   fips
# 0              5897  2010  08025
# 1             30533  2010  08029
# 2            578087  2010  08031
# 3              2027  2010  08033
# 4            273440  2010  08035

# %%
housingdata = load_data('housing')
housingdata['fips'] = housingdata['id'].apply(lambda s: s[-5:])
housingdata = housingdata.drop(columns=['id', 'geographic area name', 'boat rv van etc., '1-unit attached'])
housingdata.head()
# Out:
#    occupied housing units 1-unit, attached 2 units 3 or 4 units 5 to 9 units  \
# 0                    3339               21      57           65            0
# 1                   20917              234     639          231          215
# 2                    4998               81      68           48           26
# 3                    5567               44     152          263           99
# 4                    6281               66     323           84          293
#
#   10 to 19 units 20 or more units mobile home boat, rv, van, etc.  year  \
# 0             19                0        1148                   0  2010
# 1            217               55        4264                  45  2010
# 2              9               28        1053                   0  2010
# 3              8                0        2056                   0  2010
# 4              0               72        1709                   0  2010
#
#    1-unit attached  boat rv van etc.   fips
# 0              NaN               NaN  13155
# 1              NaN               NaN  13157
# 2              NaN               NaN  13159
# 3              NaN               NaN  13161
# 4              NaN               NaN  13163

# %%
commutedata = load_data('commute')
commutedata['fips'] = commutedata['id'].apply(lambda s: s[-5:])
commutedata = commutedata.drop(columns=['id', 'geographic area name'])
commutedata.head()
# Out:
#    commute time  year   fips
# 0        8685.0  2010  30019
# 1       96535.0  2010  72073
# 2      304545.0  2010  24023
# 3     1161730.0  2010  39173
# 4        4905.0  2010  30079

# %%
m1 = educationdata.merge(incomedata, how='inner', on=['fips', 'year'])
m1.head()
# Out:
#    9th to 12th grade, no diploma  high school graduate (includes equivalency)  \
# 0                            8.4                                         36.7
# 1                            7.1                                         39.3
# 2                           16.1                                         32.3
# 3                            8.2                                         24.7
# 4                            9.2                                         35.0
#
#    some college, no degree  associate's degree  bachelor's degree  \
# 0                     25.1                 9.3                8.9
# 1                     19.6                 7.2               14.5
# 2                     24.6                 8.3                9.4
# 3                     19.6                 7.0               20.9
# 4                     23.9                 8.9               10.8
#
#    graduate or professional degree  year   fips         geographic area name  \
# 0                              7.2  2010  17083      Jersey County, Illinois
# 1                              8.5  2010  17085  Jo Daviess County, Illinois
# 2                              3.4  2010  17087     Johnson County, Illinois
# 3                             10.9  2010  17089        Kane County, Illinois
# 4                              6.6  2010  17091    Kankakee County, Illinois
#
#   median income (family) median income (nonfamily)
# 0                  64773                     28125
# 1                  60381                     28266
# 2                  47423                     21378
# 3                  77998                     40333
# 4                  59998                     28864

# %%
m2 = m1.merge(populationdata, how='inner', on=['fips', 'year'])
m2.head()
# Out:
#    9th to 12th grade, no diploma  high school graduate (includes equivalency)  \
# 0                            8.4                                         36.7
# 1                            7.1                                         39.3
# 2                           16.1                                         32.3
# 3                            8.2                                         24.7
# 4                            9.2                                         35.0
#
#    some college, no degree  associate's degree  bachelor's degree  \
# 0                     25.1                 9.3                8.9
# 1                     19.6                 7.2               14.5
# 2                     24.6                 8.3                9.4
# 3                     19.6                 7.0               20.9
# 4                     23.9                 8.9               10.8
#
#    graduate or professional degree  year   fips         geographic area name  \
# 0                              7.2  2010  17083      Jersey County, Illinois
# 1                              8.5  2010  17085  Jo Daviess County, Illinois
# 2                              3.4  2010  17087     Johnson County, Illinois
# 3                             10.9  2010  17089        Kane County, Illinois
# 4                              6.6  2010  17091    Kankakee County, Illinois
#
#   median income (family) median income (nonfamily)  total population
# 0                  64773                     28125             22932
# 1                  60381                     28266             22728
# 2                  47423                     21378             12710
# 3                  77998                     40333            502628
# 4                  59998                     28864            112100

# %%
m3 = m2.merge(housingdata, how='inner', on=['fips', 'year'])
m3.head()
# Out:
#    9th to 12th grade, no diploma  high school graduate (includes equivalency)  \
# 0                            8.4                                         36.7
# 1                            7.1                                         39.3
# 2                           16.1                                         32.3
# 3                            8.2                                         24.7
# 4                            9.2                                         35.0
#
#    some college, no degree  associate's degree  bachelor's degree  \
# 0                     25.1                 9.3                8.9
# 1                     19.6                 7.2               14.5
# 2                     24.6                 8.3                9.4
# 3                     19.6                 7.0               20.9
# 4                     23.9                 8.9               10.8
#
#    graduate or professional degree  year   fips         geographic area name  \
# 0                              7.2  2010  17083      Jersey County, Illinois
# 1                              8.5  2010  17085  Jo Daviess County, Illinois
# 2                              3.4  2010  17087     Johnson County, Illinois
# 3                             10.9  2010  17089        Kane County, Illinois
# 4                              6.6  2010  17091    Kankakee County, Illinois
#
#   median income (family) median income (nonfamily)  total population  \
# 0                  64773                     28125             22932
# 1                  60381                     28266             22728
# 2                  47423                     21378             12710
# 3                  77998                     40333            502628
# 4                  59998                     28864            112100
#
#    occupied housing units 1-unit, attached 2 units 3 or 4 units 5 to 9 units  \
# 0                    8626              149     248          158          250
# 1                   10001              633     296          399          301
# 2                    4396               15      95          148           86
# 3                  168980            17314    8362         6600         8183
# 4                   40943             1807    1763         2070         2103
#
#   10 to 19 units 20 or more units mobile home boat, rv, van, etc.  \
# 0             99              145         737                  14
# 1            134              166         455                   0
# 2             27               16        1512                   2
# 3           5008             8447        1243                   0
# 4            870             1327        3114                   3
#
#    1-unit attached  boat rv van etc.
# 0              NaN               NaN
# 1              NaN               NaN
# 2              NaN               NaN
# 3              NaN               NaN
# 4              NaN               NaN

# %%
m4 = m3.merge(commutedata, how='inner', on=['fips', 'year'])
m4['commute time'] = m4['commute time'] / m4['total population']
m4.head()
# Out:
#    9th to 12th grade, no diploma  high school graduate (includes equivalency)  \
# 0                            8.4                                         36.7
# 1                            7.1                                         39.3
# 2                           16.1                                         32.3
# 3                            8.2                                         24.7
# 4                            9.2                                         35.0
#
#    some college, no degree  associate's degree  bachelor's degree  \
# 0                     25.1                 9.3                8.9
# 1                     19.6                 7.2               14.5
# 2                     24.6                 8.3                9.4
# 3                     19.6                 7.0               20.9
# 4                     23.9                 8.9               10.8
#
#    graduate or professional degree  year   fips         geographic area name  \
# 0                              7.2  2010  17083      Jersey County, Illinois
# 1                              8.5  2010  17085  Jo Daviess County, Illinois
# 2                              3.4  2010  17087     Johnson County, Illinois
# 3                             10.9  2010  17089        Kane County, Illinois
# 4                              6.6  2010  17091    Kankakee County, Illinois
#
#   median income (family) median income (nonfamily)  total population  \
# 0                  64773                     28125             22932
# 1                  60381                     28266             22728
# 2                  47423                     21378             12710
# 3                  77998                     40333            502628
# 4                  59998                     28864            112100
#
#    occupied housing units 1-unit, attached 2 units 3 or 4 units 5 to 9 units  \
# 0                    8626              149     248          158          250
# 1                   10001              633     296          399          301
# 2                    4396               15      95          148           86
# 3                  168980            17314    8362         6600         8183
# 4                   40943             1807    1763         2070         2103
#
#   10 to 19 units 20 or more units mobile home boat, rv, van, etc.  \
# 0             99              145         737                  14
# 1            134              166         455                   0
# 2             27               16        1512                   2
# 3           5008             8447        1243                   0
# 4            870             1327        3114                   3
#
#    1-unit attached  boat rv van etc.  commute time
# 0              NaN               NaN     13.279042
# 1              NaN               NaN      9.353881
# 2              NaN               NaN      7.024784
# 3              NaN               NaN     13.112819
# 4              NaN               NaN      9.937511

# %%
m4['commute time'].describe()
# Out:
# count    29822.000000
# mean         9.386683
# std          2.498992
# min          1.411674
# 25%          7.748248
# 50%          9.151568
# 75%         10.779852
# max         23.290487
# Name: commute time, dtype: float64

# %%
def first(x):
    return s[0]

# %%
vehicledata_new = vehicledata.groupby(['fips', 'year']).aggregate('first').reset_index()

# %%
vehicledata_new.shape
# Out:
# (6920, 5)

# %%
masterdf = m4.merge(vehicledata_new, how='inner', left_on=['fips', 'year'], right_on=['fips', 'year'])

# masterdf = m3.merge(vehicledata, how='left', left_on='fips', right_on='fips')
# masterdf = masterdf.dropna(axis=0, subset=['count'])
print(masterdf.shape)
masterdf.head(25)
# Out:
# (5148, 27)
#     9th to 12th grade, no diploma  \
# 0                             6.6
# 1                             9.8
# 2                             5.9
# 3                            10.8
# 4                             6.4
# 5                            13.9
# 6                             8.8
# 7                            10.2
# 8                             4.1
# 9                            10.2
# 10                            7.6
# 11                            7.7
# 12                            4.3
# 13                           10.8
# 14                            7.9
# 15                            9.7
# 16                           12.1
# 17                            7.3
# 18                            6.0
# 19                           11.5
# 20                            7.3
# 21                            5.1
# 22                            7.5
# 23                            6.3
# 24                            6.2
#
#     high school graduate (includes equivalency)  some college, no degree  \
# 0                                          20.3                     18.4
# 1                                          30.5                     28.5
# 2                                          19.7                     22.3
# 3                                          23.2                     22.6
# 4                                          26.0                     29.3
# 5                                          26.8                     22.7
# 6                                          32.9                     28.9
# 7                                          21.3                     18.8
# 8                                          12.8                     18.5
# 9                                          20.6                     19.6
# 10                                         20.5                     23.0
# 11                                         18.6                     20.9
# 12                                         20.9                     27.4
# 13                                         26.2                     24.9
# 14                                         22.4                     25.6
# 15                                         23.5                     23.8
# 16                                         26.8                     24.1
# 17                                         19.8                     23.1
# 18                                         14.4                     14.5
# 19                                         27.2                     23.7
# 20                                         22.0                     25.6
# 21                                         17.8                     19.0
# 22                                         18.5                     22.3
# 23                                         16.5                     17.2
# 24                                         16.8                     22.0
#
#     associate's degree  bachelor's degree  graduate or professional degree  \
# 0                  6.9               24.0                             16.3
# 1                  9.5               13.2                              5.8
# 2                  8.2               24.5                             13.7
# 3                  7.6               13.4                              6.3
# 4                  8.8               17.7                              8.6
# 5                  6.9                9.8                              4.8
# 6                  8.1               11.7                              4.7
# 7                  6.8               19.0                              9.9
# 8                  6.4               31.5                             22.7
# 9                  7.2               14.2                              9.2
# 10                 8.7               19.8                             10.2
# 11                 7.9               23.5                             12.4
# 12                10.6               23.2                             10.9
# 13                 7.6               13.3                              7.2
# 14                 9.2               19.0                              8.9
# 15                 8.2               13.2                              5.1
# 16                 8.3               12.1                              6.3
# 17                 8.3               21.3                             12.7
# 18                 5.6               31.5                             19.7
# 19                 8.3               12.2                              5.3
# 20                 9.9               19.2                             11.4
# 21                 7.7               27.0                             17.0
# 22                 8.4               18.6                             12.4
# 23                 7.4               25.7                             19.6
# 24                 8.0               23.3                             13.9
#
#     year   fips                geographic area name median income (family)  \
# 0   2010  06001          Alameda County, California                  85014
# 1   2010  06005           Amador County, California                  65103
# 2   2010  06013     Contra Costa County, California                  91791
# 3   2010  06019           Fresno County, California                  52306
# 4   2010  06023         Humboldt County, California                  53221
# 5   2010  06029             Kern County, California                  51311
# 6   2010  06033             Lake County, California                  50140
# 7   2010  06037      Los Angeles County, California                  61622
# 8   2010  06041            Marin County, California                 112911
# 9   2010  06053         Monterey County, California                  63372
# 10  2010  06055             Napa County, California                  80030
# 11  2010  06059           Orange County, California                  83735
# 12  2010  06061           Placer County, California                  89196
# 13  2010  06065        Riverside County, California                  64787
# 14  2010  06067       Sacramento County, California                  66003
# 15  2010  06069       San Benito County, California                  75051
# 16  2010  06071   San Bernardino County, California                  61526
# 17  2010  06073        San Diego County, California                  73560
# 18  2010  06075    San Francisco County, California                  85778
# 19  2010  06077      San Joaquin County, California                  61292
# 20  2010  06079  San Luis Obispo County, California                  72054
# 21  2010  06081        San Mateo County, California                 101578
# 22  2010  06083    Santa Barbara County, California                  69190
# 23  2010  06085      Santa Clara County, California                 100733
# 24  2010  06087       Santa Cruz County, California                  80264
#
#    median income (nonfamily)  total population  occupied housing units  \
# 0                      44439           1477980                  532026
# 1                      33411             38327                   14715
# 2                      47627           1024809                  368087
# 3                      28843            908830                  283836
# 4                      24568            133058                   54276
# 5                      29291            815693                  248057
# 6                      21906             64371                   25180
# 7                      40208           9758256                 3217889
# 8                      55060            248601                  102727
# 9                      41786            407435                  124963
# 10                     42262            134051                   49179
# 11                     49389           2965525                  984503
# 12                     39065            336477                  129153
# 13                     34252           2109464                  666906
# 14                     39013           1395144                  508499
# 15                     37901             54492                   16812
# 16                     34123           2005287                  596125
# 17                     43022           3022468                 1061789
# 18                     58139            789172                  335956
# 19                     32603            673613                  212905
# 20                     31478            265577                  102434
# 21                     55812            704327                  255758
# 22                     41005            416051                  141793
# 23                     55905           1739396                  596747
# 24                     41621            256901                   93802
#
#    1-unit, attached 2 units 3 or 4 units 5 to 9 units 10 to 19 units  \
# 0             43851   24027        41212        32936          31836
# 1               520     342          317          113            181
# 2             31298    7557        20947        19213          13795
# 3              7337    9631        22999        23262           8392
# 4              2040    2646         3467         2364           1382
# 5              7161    8985        18937        10957           4026
# 6               629     563          610          622            345
# 7            225147   83810       197370       271983         267974
# 8             11144    3520         4664         6536           5946
# 9              9040    4407         8493        10708           6071
# 10             2842    1908         2180         2255           1832
# 11           126106   18145        73281        68614          61369
# 12             4007    1839         6370         7696           3880
# 13            50402   10342        27622        31162          24972
# 14            34708   12725        32204        35936          29125
# 15              715     528          929          395            421
# 16            24406   11928        32782        29230          22954
# 17           103398   25643        58615        87423          80295
# 18            58952   37595        42179        37088          37656
# 19            12137    5081         9665         9108           5966
# 20             6407    3269         5699         4543           2694
# 21            24891    5545        11859        17546          15440
# 22            10154    5080         9859        11612           8942
# 23            61120   11545        36913        35419          33713
# 24             9351    3917         5665         4154           2837
#
#    20 or more units mobile home boat, rv, van, etc.  1-unit attached  \
# 0             89559        7154                 612              NaN
# 1               391        1341                   2              NaN
# 2             32893        7131                 231              NaN
# 3             15799       14054                 410              NaN
# 4              1672        5841                 156              NaN
# 5              7929       21983                 470              NaN
# 6               616        7864                 117              NaN
# 7            611675       55346                2588              NaN
# 8              9192        1568                 382              NaN
# 9              7244        5538                 111              NaN
# 10             2482        3684                  58              NaN
# 11           130678       32898                 740              NaN
# 12             5683        4081                 152              NaN
# 13            32164       74902                2060              NaN
# 14            38875       14124                 636              NaN
# 15              269         824                   4              NaN
# 16            34189       42305                 977              NaN
# 17           156817       43959                1052              NaN
# 18            93496         387                 208              NaN
# 19            13471        8122                 389              NaN
# 20             4433       10300                 236              NaN
# 21            37036        2642                 521              NaN
# 22             9467        7660                 139              NaN
# 23            87392       18582                 378              NaN
# 24             5698        6707                 179              NaN
#
#     boat rv van etc.  commute time  count                  county state
# 0                NaN     12.456474     20          Alameda County    CA
# 1                NaN      9.893939      1           Amador County    CA
# 2                NaN     13.799532     10     Contra Costa County    CA
# 3                NaN      8.000660      2           Fresno County    CA
# 4                NaN      7.378587      2         Humboldt County    CA
# 5                NaN      8.411100      1             Kern County    CA
# 6                NaN      9.292694      1             Lake County    CA
# 7                NaN     12.477287    360      Los Angeles County    CA
# 8                NaN     12.429375     15            Marin County    CA
# 9                NaN      9.054819      1         Monterey County    CA
# 10               NaN     10.642554      4             Napa County    CA
# 11               NaN     11.756455     38           Orange County    CA
# 12               NaN     11.339467      5           Placer County    CA
# 13               NaN     12.008849      4        Riverside County    CA
# 14               NaN     10.715589      6       Sacramento County    CA
# 15               NaN     12.848216      1       San Benito County    CA
# 16               NaN     11.344783      4   San Bernardino County    CA
# 17               NaN     10.852323     29        San Diego County    CA
# 18               NaN     15.100390     24    San Francisco County    CA
# 19               NaN     11.078379      1      San Joaquin County    CA
# 20               NaN      8.518810      1  San Luis Obispo County    CA
# 21               NaN     11.823947     50        San Mateo County    CA
# 22               NaN      8.341790     11    Santa Barbara County    CA
# 23               NaN     10.911408     93      Santa Clara County    CA
# 24               NaN     11.418873      6       Santa Cruz County    CA

# %%
masterdf.to_csv('data/clean/masterdata.csv', index=False)

# %%
m4.to_csv('data/clean/masterdata_allcounties.csv', index=False)
